# %% [markdown]
# # RACCOLTA DEI DATI - Utenti
# **didatticaadistanza**
#
# Raccolta dei tweet degli utenti dal 11/03/2020 al 11/03/2022, utilizzando la libreria di scraping [Twint](https://github.com/twintproject/twint)

# %% [raw]
# !pip install twint #libreria py x scraping dati (estrazione di dati da siti web)
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %% [raw]
# !pip install twint

# %% [raw]
# import os
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import networkx as nx
#
# import powerlaw
# import seaborn as sns
# import matplotlib.colors as mcolors
# import pickle
#
# warnings.filterwarnings('ignore')
#
# from operator import itemgetter
# from collections import Counter
# warnings.filterwarnings('ignore')

# %%
import twint
from os import mkdir, path
import pandas as pd
import numpy as np 
import nest_asyncio
from glob import glob
import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_columns", 50)

# %%
from datetime import date, datetime, timedelta
from string import ascii_letters, digits
nest_asyncio.apply()

# %%
def clean_name(dirname):
    valid = set(ascii_letters + digits)
    return ''.join(a for a in dirname if a in valid)

# %%
def twint_search(hashtag, since, until, json_name):
    
    c = twint.Config()
    #c.Username = username
    c.Search = hashtag
    c.Store_json = True
    c.Output = json_name
    c.Since = since
    c.Until = until
    c.Verified = True
    #c.Lang = "it"
    #c.Limit = 1000
    try:
        twint.run.Search(c)    
    except (KeyboardInterrupt, SystemExit):
        raise
    except:
        print("Problem with %s." % since)

# %%
def twint_loop(searchterm, since, until):

    dirname = clean_name(searchterm)
    try:
    # Create target Directory
        mkdir(dirname)
        print("Directory" , dirname ,  "Created ")
    except FileExistsError:
        print("Directory" , dirname ,  "already exists")

    daterange = pd.date_range(since, until)

    for start_date in daterange:

        since = start_date.strftime("%Y-%m-%d")
        until = (start_date + timedelta(days=1)).strftime("%Y-%m-%d")

        json_name = '%s.json' % since
        json_name = path.join(dirname, json_name)

        print('Getting %s ' % since )
        twint_search(searchterm, since, until, json_name)

# %%
def creazione_df(name):
    file_names = glob(path.join(name,'*.json'))
    dfs = [pd.read_json(fn, lines = True) for fn in file_names]
    dfdad = pd.concat(dfs)
    dfdad_it = dfdad[dfdad["language"] == "it"]
    dfdad_it.to_csv('data_verified/'+name+".csv")

# %%
def scraping_creazione_df(name, start, end):
    twint_loop(name, start, end)
    creazione_df(name)

# %%
scraping_creazione_df('didatticaadistanza', '2020-03-01', '2022-03-01')
# Out:
# Directory didatticaadistanza Created
# Getting 2020-03-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-02
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-04
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-05
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-06
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-07
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-08
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-09
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-10
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-11
# 1237732721805398016 2020-03-11 14:30:51 +0200 <AIRC_it> 📚 #Didatticaadistanza: sul sito di AIRC per le #scuola sono disponibili tanti contenuti e strumenti gratuiti per gli studenti e i docenti delle scuole di ogni ordine e grado. #scuolechiuse ⤵   https://t.co/rEmphknBWd
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-12
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-13
# 1238427084684435456 2020-03-13 12:30:00 +0200 <WikimediaItalia> #didatticaadistanza: con i progetti #Wikimedia e #OpenStreetMap si può fare! I docenti che hanno seguito i nostri corsi riconosciuti da @MiurSocial stanno portando avanti attività con le loro classi anche in questo periodo di chiusura delle scuole ➡️  https://t.co/0FUiioCuct  https://t.co/OKEfonA2kr
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-14
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-15
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-16
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03-17
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-04
# 1324080700719419392 2020-11-04 21:06:53 +0200 <bravoAlvin> Pronti amici ?  Scuola a Distanza etc etc... 🥂#dpcm #didatticaadistanza #teniamoduro  https://t.co/TrUXE38q5k
# 1323937782734200835 2020-11-04 11:38:59 +0200 <terry_manzo> €500.000, questa la cifra destinata alle scuole dei nostri comuni del Collegio #Campania 1 - 3 per adeguare gli istituti scolastici con strumenti all’avanguardia che possano facilitare anche i processi di #didatticaadistanza.  https://t.co/mCm8OmshCa
# 1323897774958673928 2020-11-04 09:00:01 +0200 <timbusiness> #TIM ha siglato oltre 20 accordi con i principali Atenei italiani per sostenere la #didatticaadistanza. Leggi di più nella #rassegnastampa di oggi #4novembre.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-05
# 1324292364098297857 2020-11-05 11:07:58 +0200 <Affaritaliani> In #Puglia resta in vigore l’ordinanza del 28 ottobre 2020: la nota con precisazione di @micheleemiliano e @ProfLopalco #dpcm3novembre #Regioni #zonerosse #zonearancioni #didatticaadistanza #Lockdown2 #lockdownitalia    https://t.co/XxxgYxX1Tw
# 1324245141247447042 2020-11-05 08:00:19 +0200 <RegLombardia> #Covid19 #RegioneLombardia mette a disposizione delle università pubbliche lombarde 43,5mln di euro per l’acquisto di strumentazioni digitali per la #didatticaadistanza e per gli investimenti degli atenei in infrastrutture di ricerca e innovazione. ➡️  https://t.co/Z0de2LpOz9  https://t.co/jM0CFwzvwl
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-06
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-07
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-08
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-09
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-10
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-11
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-12
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-13
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-14
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-15
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-16
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-17
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2020-11-18
# 1329072493584257027 2020-11-18 15:42:30 +0200 <M5S_Camera> 🔴 I nostri deputati @RTestamento e Marco Bella intervengono ora nell'Aula di Montecitorio interrogando la ministra dell'Istruzione, @AzzolinaLucia, sulle iniziative realizzate per formare i nostri docenti alla #didatticaadistanza.  Collegatevi! ⤵️  https://t.co/Y3iSyj1dzU
# 1329072461069991939 2020-11-18 15:42:22 +0200 <Mov5Stelle> 🔴 I nostri deputati @RTestamento e Marco Bella intervengono ora nell'Aula di Montecitorio interrogando la ministra dell'Istruzione, @AzzolinaLucia, sulle iniziative realizzate per formare i nostri docenti alla #didatticaadistanza.  Collegatevi! ⤵️  https://t.co/YaW9mTXHhF
# ...
# found 0 deleted tweets in this search.
# Getting 2021-09-25
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-09-26
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-09-27
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-09-28
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-09-29
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-09-30
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-02
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-04
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-05
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-06
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-07
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-08
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-09
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-10
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-11
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-12
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-13
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-14
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-15
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-16
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-17
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-18
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-19
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-20
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-21
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-22
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-23
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-24
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-25
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-26
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-27
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-28
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-29
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-30
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-10-31
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-02
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-04
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-05
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-06
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-07
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-08
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-09
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-10
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-11
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-12
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-13
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-14
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-15
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-16
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-17
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-18
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-19
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-20
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-21
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-22
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-23
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-24
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-25
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-26
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-27
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-28
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-29
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-11-30
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-02
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-04
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-05
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-06
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-07
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-08
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-09
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-10
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-11
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-12
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-13
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-14
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-15
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-16
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-17
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-18
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-19
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-20
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-21
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-22
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-23
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-24
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-25
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-26
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-27
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-28
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-29
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-30
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2021-12-31
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-02
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-04
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-05
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-06
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-07
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-08
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-09
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-10
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-11
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-12
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-13
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-14
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-15
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-16
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-17
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-18
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-19
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-20
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-21
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-22
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-23
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-24
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-25
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-26
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-27
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-28
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-29
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-30
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-01-31
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-02
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-04
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-05
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-06
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-07
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-08
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-09
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-10
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-11
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-12
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-13
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-14
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-15
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-16
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-17
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-18
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-19
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-20
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-21
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-22
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-23
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-24
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-25
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-26
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-27
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-02-28
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-03-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %% [raw]
# file_names = glob(path.join('PresidentKR','*.json'))
# dfs = [pd.read_json(fn, lines = True) for fn in file_names]
# dftrial = pd.concat(dfs)
# #dftrial = pd.concat(dfs)
# dftrial_en = dftrial[dftrial["language"] == "en"]
# info_df.append(('PresidentKR', dftrial_en.shape))
# dftrial_en.to_csv('data/PresidentKR.csv')
